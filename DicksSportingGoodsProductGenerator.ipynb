# %%
import re
import os
import numpy as np
import pandas as pd
from datetime import datetime
import time
from datetime import datetime, timedelta
from pytz import timezone
import pytz
from dateutil.parser import parse
from collections import deque 
import csv

# %%
data = pd.read_csv("/Users/haleyhowell/dicksData/customerData.csv")

# %%
data.head()
# Out:
#    UserId  CustomerSince  CustomerSinceTier  Location  ShoeSize ShirtSize  \
# 0       1              4                  3         1       7.5         S
# 1       2              2                  2         2       8.0        XS
# 2       3              5                  4         3       9.0         M
# 3       4              7                  4         4      12.0         S
# 4       5              9                  4         5      13.0         M
#
#   PantSize               AverageCategory  NumberofCartOnlyEvents  \
# 0        S                         Pants                       2
# 1       XS                        Shirts                       2
# 2        L                         Pants                       4
# 3        M                         Shoes                       1
# 4        L  Men's Cold Weather Golf Tops                       1
#
#    InStoreTransactions     ...      InStoreConversionTier  OnlineTransactions  \
# 0                    3     ...                          4                  10
# 1                    1     ...                          4                   6
# 2                   15     ...                          5                  15
# 3                   25     ...                          5                   0
# 4                   30     ...                          5                   4
#
#    OnlineVisits  OnlineConversion  OnlineConversionTier  DiscountsUsed  \
# 0            25          0.400000                     4              2
# 1            15          0.400000                     4              1
# 2            23          0.652174                     5              3
# 3             3          0.000000                     0             10
# 4             7          0.571429                     5              6
#
#    DiscountTier  AverageSpentPerTransaction  AverageSpentTier  TotalSpent
# 0             3                       30.33                 4         390
# 1             2                       40.04                 4         280
# 2             4                       35.15                 4        1050
# 3             5                       60.03                 5        1500
# 4             5                       45.13                 5        1530
#
# [5 rows x 22 columns]
