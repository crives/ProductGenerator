# %%
import re
import os
import numpy as np
import pandas as pd
from datetime import datetime
import time
from datetime import datetime, timedelta
from pytz import timezone
import pytz
from dateutil.parser import parse
from collections import deque 
import csv

# %%
customers = pd.read_csv("/Users/carolinerives/Desktop/DSG-Project/CustomerData.csv")

# Haley Path: (uncomment and put your path here:)

# customers = pd.read_csv("/Users/")

# %%
customers.head()
# Out:
#   UserId CustomerName  CustomerSince  CustomerSinceTier  Location  ShoeSize  \
# 0      1    customer1            4.0                3.0       1.0       7.5
# 1      2    customer2            2.0                2.0       2.0       8.0
# 2      3    customer3            5.0                4.0       3.0       9.0
# 3      4    customer4            7.0                4.0       4.0      12.0
# 4      5    customer5            9.0                4.0       5.0      13.0
#
#   ShirtSize PantSize               AverageCategory  NumberofCartOnlyEvents  \
# 0         S        S                         Pants                     2.0
# 1        XS       XS                        Shirts                     2.0
# 2         M        L                         Pants                     4.0
# 3         S        M                         Shoes                     1.0
# 4         M        L  Men's Cold Weather Golf Tops                     1.0
#
# ...

# %%
 products = pd.read_csv("/Users/carolinerives/Desktop/DSG-Project/formatted-golf-galaxy-products.csv")
    
# Haley Path: (uncomment and put your path here:)

# products = pd.read_csv("/Users/")

# %%
products.head()
# Out:
#                                             prodName  \
# 0         Nike Hyperfuel 32 oz. Squeeze Water Bottle
# 1       Under Armour Men's Elements Golf Rain Jacket
# 2               Cutter & Buck Men's Fusion Golf Polo
# 3  Walter Hagen Men's 11 Majors Championship Stri...
# 4    Feetures! Elite Light Cushion No Show Tab Socks
#
#                                             prodLink  \
# 0  https://www.golfgalaxy.com/p/nike-hyperfuel-32...
# 1  https://www.golfgalaxy.com/p/under-armour-mens...
# 2  https://www.golfgalaxy.com/p/cutter-buck-mens-...
# 3  https://www.golfgalaxy.com/p/walter-hagen-mens...
# 4  https://www.golfgalaxy.com/p/feetures-elite-li...
#
#                prodColorText  \
# 0  Fire Pnk/Blk/Blk/Ghost Gr
# 1                        NaN
# 2                        NaN
# 3                       Navy
# 4                        NaN
#
#                                            prodSizes prodHiglights  \
# ...

# %%
# Create a function where you create a column "Category". 
# Put the column name for category in the cell that = 1. 
# Rename col to "Category".

# %%
for index in customers.iterrows():
#     print(customers)
    customer = customers['CustomerName'][index]
    avg_spend_tier = customer['AverageSpentTier']
    disc_tier = customer['DiscountTier']
    cust_cat = customer['AverageCategory']
#     twenty_above = 
#     top_items =
        
    if(customer['InStoreConversionTier'] > 2):
        if(disc_tier > 2):
            if(products[products['Category'].str.contains(cust_cat)] and disc_tier != 0 and products['prodSalePrice'] < twenty_above):
                
                products[products['Category'].str.contains(cust_cat)]
                    filter = products['prodSalePrice']< twenty_above

                products.where(filter, inplace = True) 

                return products


            else if(products[products['Category'].str.contains(cust_cat)] and products['prodSalePrice'] < twenty_above):
        
                products[products['Category'].str.contains(cust_cat)]
                    filter = products['prodSalePrice']< twenty_above

                products.where(filter, inplace = True) 

                return products
    
    else if(disc_tier > 2):
        
        if(products[products['Category'].str.contains(cust_cat)] and disc_tier != 0 and products['prodSalePrice'] < twenty_above):
                
                products[products['Category'].str.contains(cust_cat)]
                    filter = products['prodSalePrice']< twenty_above

                products.where(filter, inplace = True) 

                return products
        
        else
        if(products[products['prodName'].str.contains(top_items)] and products['prodStarRating'] == 4 | 5 and products['prodSalePrice'] < twenty_above) 

            products[products['prodName'].str.contains(top_items)]
                filter = products['Rating'] == 4 | 5
    
            products.where(filter, inplace=True)
                filter = products['prodSalePrice'] < twenty_above
            
            products.where(filter, inplace=True)
            
            return products
# Out:
#        UserId CustomerName  CustomerSince  CustomerSinceTier  Location  \
# 0           1    customer1            4.0                3.0       1.0
# 1           2    customer2            2.0                2.0       2.0
# 2           3    customer3            5.0                4.0       3.0
# 3           4    customer4            7.0                4.0       4.0
# 4           5    customer5            9.0                4.0       5.0
# 5           6    customer6            2.0                2.0       6.0
# 6           7    customer7            3.0                3.0       7.0
# 7           8    customer8            3.0                3.0       8.0
# 8           9    customer9           10.0                5.0       9.0
# 9          10   customer10            6.0                4.0      10.0
# 10         11   customer11           10.0                5.0       1.0
# 11         12   customer12            5.0                4.0       2.0
# ...
